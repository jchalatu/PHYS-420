# %% [markdown]
# # PHYS 420 Assigment 1

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import *
from IPython.display import display, Math, Latex, Markdown

# %% [markdown]
# ### <u>Q1</u>: Plotting sine and cosine

# %%
x = np.linspace(0,2*pi,100)
y1 = cos(x)
y2 = sin(x)
font_size = 18

plt.figure(1,figsize = (9,5))
plt.plot(x,y1,'m.')
plt.xlabel('x',fontsize = font_size)
plt.ylabel('cos(x)',fontsize = font_size)

plt.figure(2,figsize = (9,5))
plt.plot(x,y2,'m.')
plt.xlabel('x',fontsize = font_size)
plt.ylabel('sin(x)',fontsize = font_size)
plt.show()

# %% [markdown]
# ### <u>Q2</u>: Numerical derivative of f(x) = x + 3sin(x)

# %%
def deriv(fx,fx_h,h):
    dx = (fx_h-fx)/h
    return dx

def func(x):
    return x + 3.0*sin(x)

def analytic(x):
    return 1.0 + 3.0*cos(x)

# %%
powers = np.arange(-1,-14,-2)
fx = func(x)
fig_num = 1
for n in powers:
    h = 10.**n
    fx_h = func(x+h)
    dfdx = deriv(fx,fx_h,h)
    diff = dfdx - analytic(x)
    sum_sqrs = np.sum(diff**2.)
    displ_h = 'h: %1.e'%(h)
    displ_sum = 'Sum of Squares: %.5e'%(sum_sqrs)
    display(Markdown(displ_h))
    display(Markdown(displ_sum))
    plt.figure(fig_num,figsize = (9,5))
    plt.plot(x,diff,'m.')
    plt.xlabel('x',fontsize = font_size)
    plt.ylabel(r"$f^{ \ '}(x) - 1 -3\rm{cos}(x)$", fontsize = font_size)
    plt.show()
# Out:
# h: 1e-01
# Sum of Squares: 1.11316e+00
# h: 1e-03
# Sum of Squares: 1.11375e-04
# h: 1e-05
# Sum of Squares: 1.11374e-08
# h: 1e-07
# Sum of Squares: 1.15019e-12
# h: 1e-09
# Sum of Squares: 9.51630e-12
# h: 1e-11
# Sum of Squares: 1.05833e-07
# h: 1e-13
# Sum of Squares: 4.53376e-03

# %% [markdown]
# ### <u>Q3</u>: Symmetric derivative of f(x) = x + 3sin(x)

# %%
def sym_deriv(fx_p,fx_n,h):
    dx = (fx_p-fx_n)/(2.*h)
    return dx

# %%
fig_num = 1
for n in powers:
    h = 10.**n
    fx_p = func(x+h)
    fx_n = func(x-h)
    dfdx = sym_deriv(fx_p,fx_n,h)
    diff = dfdx - analytic(x)
    sum_sqrs = np.sum(diff**2)
    displ_h = 'h: %1.e'%(h)
    displ_sum = 'Sum of Squares: %.5e'%(sum_sqrs)
    display(Markdown(displ_h))
    display(Markdown(displ_sum))
    plt.figure(fig_num,figsize = (9,5))
    plt.plot(x,diff,'m.')
    plt.xlabel('x',fontsize = font_size)
    plt.ylabel(r"$f^{ \ '}(x) - 1 -3\rm{sin}(x)$", fontsize = font_size)
    plt.show()
# Out:
# h: 1e-01
# Sum of Squares: 1.61746e+01
# h: 1e-03
# Sum of Squares: 3.71818e+04
# h: 1e-05
# Sum of Squares: 5.60500e+02
# h: 1e-07
# Sum of Squares: 5.60500e+02
# h: 1e-09
# Sum of Squares: 5.60500e+02
# h: 1e-11
# Sum of Squares: 5.60500e+02
# h: 1e-13
# Sum of Squares: 5.60500e+02

# %% [markdown]
# ### <u>Q4</u>

# %%
def sym_deriv2(fx_p,fx_n,x1,x2):
    dx = (fx_p-fx_n)/(x2-x1)
    return dx

# %%
fig_num = 1
for n in powers:
    h = 10.**n
    x1 = x-h
    x2 = x+h
    fx_p = func(x2)
    fx_n = func(x1)
    dfdx = sym_deriv2(fx_p,fx_n,x1,x2)
    diff = dfdx - analytic(x)
    sum_sqrs = np.sum(diff**2)
    displ_h = 'h: %.3e'%(h)
    displ_sum = 'Sum of Squares: %.5e'%(sum_sqrs)
    display(Markdown(displ_h))
    display(Markdown(displ_sum))
    plt.figure(fig_num,figsize = (7,5))
    plt.plot(x,diff,'m.')
    plt.xlabel('x',fontsize = font_size)
    plt.ylabel(r"$f^{ \ '}(x) - 1 -3\rm{sin}(x)$", fontsize = font_size)
    plt.show()
# Out:
# h: 1.000e-01
# Sum of Squares: 1.26124e-03
# h: 1.000e-03
# Sum of Squares: 1.26250e-11
# h: 1.000e-05
# Sum of Squares: 1.42638e-19
# h: 1.000e-07
# Sum of Squares: 2.34399e-16
# h: 1.000e-09
# Sum of Squares: 2.85740e-12
# h: 1.000e-11
# Sum of Squares: 2.91429e-08
# h: 1.000e-13
# Sum of Squares: 2.96057e-04

# %% [markdown]
# ### <u>Q5</u>: Comparing analytical derivative to numerical

# %%
def func(x):
    return 1e15 + x + 3*sin(x)

f = func(x)
h = 0.2
f_h = func(x+h)
dfdx = deriv(f,f_h,h)
dfdx_analytical = 1 + 3*cos(x)

plt.figure(1,figsize = (7,5))
plt.plot(x,dfdx,'b-',label = 'Numerical Derivative')
plt.plot(x,dfdx_analytical,'m-',label = 'Analytical Derivative')
plt.xlabel('x',fontsize = font_size)
plt.ylabel(r"$f^{ \ '}(x)$",fontsize = font_size)
plt.legend(loc = 'best')
plt.show()
